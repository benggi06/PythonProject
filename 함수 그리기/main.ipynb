# %%
import print_fn
from util import util

def main():
    util.header_print('1-1 header print','2022,09,14','(c) Bang Gi Woong')
    fn=input('''함수의 종류를 입력하세요.:
    1. 2차함수 2. 사인 함수 3. 코사인 함수
     : ''')

    width =int(input('너비를 입력하세요.: '))
    height = int(input('높이를 입력하세요.: '))
    x_min=int(input('x의 최솟값을 입력하세요.: '))
    x_max=int(input('x의 최댓값을 입력하세요.: '))

    print_fn.print_fn(fn,x_min,x_max,width,height)



if __name__=='__main__':
    main()
# Out:
# *********************
# * 1-1 header print  *
# *    2022,09,14     *
# * (c) Bang Gi Woong *
# *********************
# 함수의 종류를 입력하세요.:
#     1. 2차함수 2. 사인 함수 3. 코사인 함수
#      : 1
# 너비를 입력하세요.: 30
# 높이를 입력하세요.: 30
# x의 최솟값을 입력하세요.: -3
# x의 최댓값을 입력하세요.: 3
# 2차항 계수를 입력하세요.: 1
# 1차항 계수를 입력하세요.: 0
# 상수항을 입력하세요.: 0
# 입력한 이차함수는 다음과 같습니다.: f(x) = (1)x^2+(0)x+(0)
#                             y │
#                               │
#                               │
#                               │
#                               │
#                               │
#                               │
#                         *     │     *
#                               │
#                               │
#                               │
#                               │
#                           *   │   *
#                               │
#                               │
#                             * │ *
# - - - - - - - - - - - - - - - * - - - - - - - - - - - - - - -
# ...

# %%
if __name__=='__main__':
    main()
# Out:
# *********************
# * 1-1 header print  *
# *    2022,09,14     *
# * (c) Bang Gi Woong *
# *********************
# 함수의 종류를 입력하세요.:
#     1. 2차함수 2. 사인 함수 3. 코사인 함수
#      : 2
# 너비를 입력하세요.: 71
# 높이를 입력하세요.: 360
# x의 최솟값을 입력하세요.: 0
# x의 최댓값을 입력하세요.: 360
#  x  ----------------------------------------------------------------------- sin(x)
# 000                                    *                                     0.000
# 010                                    │      *                              0.174
# 020                                    │            *                        0.342
# 030                                    │                 *                   0.500
# 040                                    │                      *              0.643
# 050                                    │                          *          0.766
# 060                                    │                              *      0.866
# ...

# %%
if __name__=='__main__':
    main()
# Out:
# *********************
# * 1-1 header print  *
# *    2022,09,14     *
# * (c) Bang Gi Woong *
# *********************
# 함수의 종류를 입력하세요.:
#     1. 2차함수 2. 사인 함수 3. 코사인 함수
#      : 3
# 너비를 입력하세요.: 71
# 높이를 입력하세요.: 360
# x의 최솟값을 입력하세요.: 0
# x의 최댓값을 입력하세요.: 360
#  x  ----------------------------------------------------------------------- cos(x)
# 000                                    │                                   * 1.000
# 010                                    │                                  *  0.985
# 020                                    │                                *    0.940
# 030                                    │                              *      0.866
# 040                                    │                          *          0.766
# 050                                    │                      *              0.643
# 060                                    │                 *                   0.500
# ...

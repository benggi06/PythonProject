# %%
import PokerUtil as pu
from util import util as hd

# %%
def main():
    hd.header_print('1-2 Caesar cipher','2022.09.14','(c) Bang, Gi-Woong')
    playerName=input('사용자의 이름을 입력해주세요.')
    dealerName=input('딜러의 이름을 입력해주세요.')
    money=int(input('시작 게임머니를 입력해 주세요.'))
    
    winOrlose=pu.pokerGame(playerName,dealerName,money)
    
    if winOrlose=='pstop':
        print('플레이어의 패배입니다.')
    elif winOrlose=='dstop':
        print('딜러의 패배입니다.')

# %%
if __name__=='__main__':
    main()
# Out:
# **********************
# * 1-2 Caesar cipher  *
# *     2022.09.14     *
# * (c) Bang, Gi-Woong *
# **********************
# 사용자의 이름을 입력해주세요.
# 딜러의 이름을 입력해주세요.
# 시작 게임머니를 입력해 주세요.10000
# 곧 포커 게임이 시작됩니다.
# •••
# 모양은 다음과 같습니다.('Club', 'Diamond', 'Heart', 'Spade')
# 숫자는 다음과 같습니다.('Ace', '2', '3', '4', '5', '6', '7', '8', '9', '10', 'Jack', 'Queen', 'King')
# 사용자: , 상대:
# 서로에게 지급된 돈은 다음과 같습니다. 10000
#
# 족보는 다음과 같습니다.
#
#     Flush : 모든 카드 모양이 동일
#     Straight: 카드가 모두 연속적일 때 ex) 1,2,3,4,5
#     Four Card: 숫자 4개가 동일할 때
#     Triple: 숫자 3개가 동일할 때
#     Two Pair: 같은 숫자를 가진것이 두 개일 때 ex) 2,2,4,4,5
#     One Pair: 같은 숫자를 가진것이 한 개일 때 ex) 2,2,3,4,5
#     High Card: 가장 높은 숫자
#
#     [주의1]: 같은 족보가 나왔을 시 Spade<- Diamond<- Heart<- Club 순으로 우위를 점합니다.
#     [주의2]: 3번째 카드부터는 상대에게 공개되지 않습니다.
#
# 다음으로 넘어가려면 엔터키를 누르세요.
# •••
# 1번째 게임이 시작됩니다.
# 현재 의 게임머니: 10000원
# 현재 의 게임머니: 10000원
#
# 이제 참가비를 거두겠습니다.
# 양측에서 1000원씩 돈이 차감됩니다.
# 덱을 만듭니다. 잠시만 기다려주세요.
# •••
# 덱이 완성되었습니다.
#
# 이제 덱을 섞겠습니다.
# •••
# 덱을 섞었습니다.
#
# ...
